# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from pandas) (2025.3)
# Requirement already satisfied: numpy>=1.22.4 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: six>=1.5 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install google-cloud-bigquery
# Out:
# Requirement already satisfied: google-cloud-bigquery in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (3.40.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-cloud-bigquery) (2.9.0.post0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-cloud-bigquery) (2.8.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-cloud-bigquery) (2.5.0)
# Requirement already satisfied: google-api-core[grpc]<3.0.0,>=2.11.1 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-cloud-bigquery) (2.29.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-cloud-bigquery) (2.41.1)
# Requirement already satisfied: requests<3.0.0,>=2.21.0 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-cloud-bigquery) (2.32.5)
# Requirement already satisfied: packaging>=24.2.0 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-cloud-bigquery) (25.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (6.33.4)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.27.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.76.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.76.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (4.9.1)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.0.0 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-resumable-media<3.0.0,>=2.0.0->google-cloud-bigquery) (1.8.0)
# Requirement already satisfied: six>=1.5 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery) (1.17.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (2026.1.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (3.4.4)
# Requirement already satisfied: typing-extensions~=4.12 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from grpcio<2.0.0,>=1.33.2->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (4.15.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (0.6.1)

# %%
# !pip install pandas-gbq
# Out:
# Collecting pandas-gbq
#   Downloading pandas_gbq-0.33.0-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 KB 3.0 MB/s eta 0:00:00ta 0:00:01
# Requirement already satisfied: setuptools in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from pandas-gbq) (59.6.0)
# Requirement already satisfied: pyarrow>=4.0.0 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from pandas-gbq) (22.0.0)
# Requirement already satisfied: google-auth-oauthlib>=0.7.0 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from pandas-gbq) (1.2.3)
# Requirement already satisfied: google-cloud-bigquery<4.0.0,>=3.20.0 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from pandas-gbq) (3.40.0)
# Requirement already satisfied: google-api-core<3.0.0,>=2.15.0 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from pandas-gbq) (2.29.0)
# Requirement already satisfied: numpy>=1.18.1 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from pandas-gbq) (2.2.6)
# Requirement already satisfied: psutil>=5.9.8 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from pandas-gbq) (7.2.1)
# Requirement already satisfied: packaging>=22.0.0 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from pandas-gbq) (25.0)
# Collecting pydata-google-auth>=1.5.0
#   Downloading pydata_google_auth-1.9.1-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: pandas<3.0.0,>=1.1.4 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from pandas-gbq) (2.3.3)
# Requirement already satisfied: google-auth>=2.14.1 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from pandas-gbq) (2.41.1)
# Collecting db-dtypes<2.0.0,>=1.0.4
#   Downloading db_dtypes-1.5.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-api-core<3.0.0,>=2.15.0->pandas-gbq) (6.33.4)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-api-core<3.0.0,>=2.15.0->pandas-gbq) (1.72.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-api-core<3.0.0,>=2.15.0->pandas-gbq) (2.32.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-api-core<3.0.0,>=2.15.0->pandas-gbq) (1.27.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-auth>=2.14.1->pandas-gbq) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-auth>=2.14.1->pandas-gbq) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-auth>=2.14.1->pandas-gbq) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-auth-oauthlib>=0.7.0->pandas-gbq) (2.0.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (2.9.0.post0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (2.8.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (2.5.0)
# Requirement already satisfied: tzdata>=2022.7 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from pandas<3.0.0,>=1.1.4->pandas-gbq) (2025.3)
# Requirement already satisfied: pytz>=2020.1 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from pandas<3.0.0,>=1.1.4->pandas-gbq) (2025.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-api-core<3.0.0,>=2.15.0->pandas-gbq) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-api-core<3.0.0,>=2.15.0->pandas-gbq) (1.76.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.0.0 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from google-resumable-media<3.0.0,>=2.0.0->google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (1.8.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.14.1->pandas-gbq) (0.6.1)
# Requirement already satisfied: six>=1.5 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (1.17.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0,>=2.15.0->pandas-gbq) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0,>=2.15.0->pandas-gbq) (3.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0,>=2.15.0->pandas-gbq) (2026.1.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0,>=2.15.0->pandas-gbq) (3.11)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.7.0->pandas-gbq) (3.3.1)
# Requirement already satisfied: typing-extensions~=4.12 in /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages (from grpcio<2.0.0,>=1.33.2->google-api-core<3.0.0,>=2.15.0->pandas-gbq) (4.15.0)
# Installing collected packages: db-dtypes, pydata-google-auth, pandas-gbq
# Successfully installed db-dtypes-1.5.0 pandas-gbq-0.33.0 pydata-google-auth-1.9.1

# %%
import pandas as pd

# %%
project_id = 'data-engineering-gcp-483907'

# %%
query = f'''
    SELECT order_status, count(*) AS order_count
    FROM `{project_id}.retail.orders`
    GROUP BY 1
    ORDER BY 2 DESC
'''

# %%
df = pd.read_gbq(query, project_id=project_id)
# Out:
# /tmp/ipykernel_3797/101979516.py:1: FutureWarning: read_gbq is deprecated and will be removed in a future version. Please use pandas_gbq.read_gbq instead: https://pandas-gbq.readthedocs.io/en/latest/api.html#pandas_gbq.read_gbq
#   df = pd.read_gbq(query, project_id=project_id)
# /home/sammigachuhi/itversity/data-engineering-on-gcp/deg-venv/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.12) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)

# %%
df
# Out:
#       order_status  order_count
# 0         COMPLETE        22899
# 1  PENDING_PAYMENT        15030
# 2       PROCESSING         8275
# 3          PENDING         7610
# 4           CLOSED         7556
# 5          ON_HOLD         3798
# 6  SUSPECTED_FRAUD         1558
# 7         CANCELED         1428
# 8   PAYMENT_REVIEW          729
